# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/kaggle/input/udemy-course/udemy_courses.csv', parse_dates=['published_timestamp'])
print(data)
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# # 1). 10 Data teratas

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# # 2). 5 Data terbawah

# %%
data.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# # 3). Jumlah Baris Dan Jumlah Kolom

# %%
data.shape

print('Jumlah baris: ', data.shape[0])
print('Jumlah kolom: ', data.shape[1])
# Out:
# Jumlah baris:  3678
# Jumlah kolom:  12

# %% [markdown]
# # 4). Informasi mengenai Dataset seperti Tipe Data Setiap Kolom Dan Kebutuhan Memori dan deskripsi (min, max, std, mean, dan lain-lain) pada tiap kolom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
data.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# # 5). Memeriksa Nilai Null Dalam Dataset

# %%
print('Nilai null: ', data.isnull().values.any())
# Out:
# Nilai null:  False

# %%
data.isnull()
# Out:
#       course_id  course_title    url  is_paid  price  num_subscribers  \
# 0         False         False  False    False  False            False
# 1         False         False  False    False  False            False
# 2         False         False  False    False  False            False
# 3         False         False  False    False  False            False
# 4         False         False  False    False  False            False
# ...         ...           ...    ...      ...    ...              ...
# 3673      False         False  False    False  False            False
# 3674      False         False  False    False  False            False
# 3675      False         False  False    False  False            False
# 3676      False         False  False    False  False            False
# 3677      False         False  False    False  False            False
#
#       num_reviews  num_lectures  level  content_duration  published_timestamp  \
# ...

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # **DATA CLEANSING**

# %% [markdown]
# # 6). Cek duplikat kemudian dibuang

# %%
duplikat = data.duplicated().any()
print('data duplikat: ', duplikat)
# Out:
# data duplikat:  True

# %%
data[data.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
data.drop_duplicates()
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 347.8+ KB

# %%
data.shape

print('Jumlah baris setelah duplikat dibuang: ', data.shape[0])
print('Jumlah kolom setelah duplikat dibuang: ', data.shape[1])
# Out:
# Jumlah baris setelah duplikat dibuang:  3672
# Jumlah kolom setelah duplikat dibuang:  12

# %% [markdown]
# # **EDA (Exploratory Data Analysis)**

# %% [markdown]
# # 7). Jumlah Mata Kuliah Per Mata Pelajaran

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='subject')
plt.xlabel('Mata Pelajaran', fontsize=13)
plt.ylabel('Jumlah kursus per Mata Pelajaran', fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # 8).  Untuk Tingkat Mana, Kursus Udemy Menyediakan Kursus

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='level')
plt.xlabel('Level/tingkatan', fontsize=13)
plt.ylabel('Jumlah kursus per Tingkatan/level', fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # 9). Jumlah Kursus Berbayar dan Gratis

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='is_paid')
plt.xlabel('Berbayar', fontsize=13)
plt.ylabel('Jumlah kursus berbayar', fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # 10).  Level Mana yang Memiliki Jumlah Pelanggan Tertinggi

# %%
sns.barplot(x='level', y='num_subscribers', data=data)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # 11). Judul Kursus Paling Populer

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %% [markdown]
# # 12). 10 Kursus Terpopuler Sesuai Jumlah Pelanggan

# %%
data.sort_values(by='num_subscribers', ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
top_10 = data.sort_values(by='num_subscribers', ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers', y='course_title', data=top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# # 13). Kursus yang Memiliki Jumlah Ulasan Tertinggi.

# %%
plt.figure(figsize=(10, 4))
sns.barplot(x='subject', y='num_reviews', data=data)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %% [markdown]
# # 14). Apakah Harga Mempengaruhi Jumlah Ulasan dan Subscribers?

# %%
plt.figure(figsize=(13,8))
sns.scatterplot(x='price', y='num_subscribers', data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %%
plt.figure(figsize=(13,8))
sns.scatterplot(x='price', y='num_reviews', data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# # 15). Jumlah Total Kursus Yang Terkait Dengan Python

# %%
data[data['course_title'].str.contains('Python', case=False)]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
kursus_python=len(data[data['course_title'].str.contains('Python', case=False)])
print('Banyaknya kursus yang terkait dengan python: ', kursus_python)
# Out:
# Banyaknya kursus yang terkait dengan python:  29

# %% [markdown]
# # 16). 10 Kursus Python Paling Populer Sesuai Jumlah Pelanggan

# %%
data[data['course_title'].str.contains('Python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
python = data[data['course_title'].str.contains('Python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers', y='course_title', data=python)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# # 17). Tahun yang Jumlah Kursus Tertinggi Diposting

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
data.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
sns.countplot(x='Year', data=data)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# # 18). Jumlah Mata Pelajaran Berdasarkan Kategori [Tahun]

# %%
data.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %% [markdown]
# **Kesimpulan**
#
# 1. Sebagian besar kursus berbayar di udemy
# 2. Kursus yang paling populer adalah web development (pengembangan web) dan business finance (keuangan).
# 3. Tingkat level tertinggi pada kursus Udemy yaitu pada “All levels” (semua level)
# 4. Pada level “All levels” dan level “Beginner level” memiliki jumlah pelanggan tertinggi
# 5. Kursus yang memiliki jumlah ulasan tertinggi yatu web development (pengembangan web)
# 6. Harga bukan merupakan indikator apakah siswa akan membeli kursus tersebut.
# 7. Jika kontennya bertambah maka harganya juga akan bertambah
# 8. Jika harganya sangat tinggi, jumlah komentar dapat meningkat =====> jika siswa membayar 200 dolar misalnya, mungkin dia akan menginvestasikan waktu dan dia akan membagikan pemikiran dan umpan baliknya tentang kursus tersebut.
# 9. Kursus python paling popular yaitu “web programming with python”
# 10. Tahun yang jumlah tertinggi diposting pada tahun 2016
